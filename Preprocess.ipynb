# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from collections import Counter

from sklearn.model_selection import train_test_split

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 200

# %%
df = pd.read_csv('data/india_fraud_cleaned.csv')
df
# Out:
#       ReportedFraud DateOfIncident            TypeOfIncident TypeOfCollission  \
# 0                 N     2015-01-09   Multi-vehicle Collision   Rear Collision
# 1                 N     2015-02-20  Single Vehicle Collision   Side Collision
# 2                 N     2015-01-14   Multi-vehicle Collision   Side Collision
# 3                 Y     2015-01-07   Multi-vehicle Collision   Side Collision
# 4                 Y     2015-02-26   Multi-vehicle Collision   Side Collision
# ...             ...            ...                       ...              ...
# 28801             N     2015-02-13  Single Vehicle Collision   Side Collision
# 28802             N     2015-01-19   Multi-vehicle Collision   Side Collision
# 28803             N     2015-01-21   Multi-vehicle Collision   Side Collision
# 28804             N     2015-01-02                Parked Car          Missing
# 28805             N     2015-01-16  Single Vehicle Collision  Front Collision
#
#       SeverityOfIncident AuthoritiesContacted IncidentState IncidentCity  \
# 0             Total Loss                Other        State9        City4
# 1           Minor Damage            Ambulance        State4        City3
# 2           Major Damage            Ambulance        State5        City2
# 3           Major Damage            Ambulance        State7        City4
# 4           Major Damage                Other        State4        City6
# ...                  ...                  ...           ...          ...
# 28801       Minor Damage                 Fire        State7        City3
# 28802         Total Loss               Police        State5        City3
# 28803         Total Loss               Police        State5        City7
# 28804     Trivial Damage                 None        State4        City7
# 28805         Total Loss               Police        State8        City7
#
#        IncidentTime  NumberOfVehicles PropertyDamage  BodilyInjuries  \
# 0                19                 3        Missing               1
# 1                14                 1        Missing               1
# 2                21                 3        Missing               0
# 3                12                 3            YES               2
# 4                 3                 3             NO               1
# ...             ...               ...            ...             ...
# 28801            16                 1             NO               1
# 28802            19                 3            YES               2
# 28803            16                 3            YES               2
# 28804            12                 1        Missing               1
# 28805            11                 1            YES               2
#
#       Witnesses PoliceReport  AmountOfTotalClaim  AmountOfInjuryClaim  \
# 0             1      Missing               43973                 9396
# 1             1          YES               62310                 6539
# 2             0      Missing               42824                 6069
# 3             0      Missing               45672                  253
# 4             2           NO               81472                 7407
# ...         ...          ...                 ...                  ...
# 28801         2      Missing               50515                 5543
# 28802         0      Missing               94920                 8678
# 28803         0           NO               87893                13224
# 28804         1      Missing                7284                  728
# 28805         3           NO               90334                15757
#
#        AmountOfPropertyClaim  AmountOfVehicleDamage  InsuredAge InsuredGender  \
# 0                       4698                  29879          58          MALE
# 1                       6539                  49232          34        FEMALE
# 2                       6069                  30686          52        FEMALE
# 3                       5741                  39678          25        FEMALE
# 4                      14813                  59252          27          MALE
# ...                      ...                    ...         ...           ...
# 28801                   5543                  39429          39          MALE
# 28802                   8738                  77504          21          MALE
# 28803                   7990                  66679          35          MALE
# 28804                   1457                   5099          40        FEMALE
# 28805                  16322                  58255          27        FEMALE
#
#       InsuredEducationLevel  InsuredOccupation InsuredHobbies  CapitalGains  \
# 0                        JD              sales    video-games             0
# 1               High School   transport-moving           polo         51300
# 2                       PhD  machine-op-inspct       exercise             0
# 3                   College    exec-managerial       exercise         47400
# 4                   Masters              sales          chess             0
# ...                     ...                ...            ...           ...
# 28801                    JD    farming-fishing     basketball             0
# 28802             Associate     prof-specialty           golf         20000
# 28803             Associate     prof-specialty           golf             0
# 28804               Masters    exec-managerial        reading             0
# 28805                   PhD       tech-support        reading         51100
#
#        CapitalLoss  CustomerLoyaltyPeriod DateOfPolicyCoverage  \
# 0           -42700                    432           1998-11-14
# 1                0                    128           2000-08-19
# 2                0                    346           2000-06-23
# 3           -56100                     42           1992-01-15
# 4                0                    109           2001-09-23
# ...            ...                    ...                  ...
# 28801            0                    251           2007-02-07
# 28802       -75000                     14           2006-10-18
# 28803       -75000                    153           2011-11-23
# 28804       -63900                    241           1997-08-04
# 28805            0                    113           2008-01-04
#
#       InsurancePolicyState Policy_CombinedSingleLimit  Policy_Deductible  \
# 0                   State2                    250/500               2000
# 1                   State2                    100/300               1000
# 2                   State1                   500/1000                745
# 3                   State2                    100/300                986
# 4                   State3                    250/500                576
# ...                    ...                        ...                ...
# 28801               State2                    250/500               1000
# 28802               State2                    100/300               1008
# 28803               State1                    100/300                660
# 28804               State3                   250/1000               1674
# 28805               State2                   250/1000                500
#
#        PolicyAnnualPremium  UmbrellaLimit InsuredRelationship VehicleMake  \
# 0                  1142.87              0           own-child    Mercedes
# 1                  1274.38        2857344           own-child      Toyota
# 2                  1269.93              0      other-relative  Volkswagen
# 3                  1218.60              0      other-relative      Toyota
# 4                  1431.02        4235779           unmarried        Ford
# ...                    ...            ...                 ...         ...
# 28801              1108.55         739864           unmarried      Nissan
# 28802              1551.84          41592           own-child      Accura
# 28803              1119.32              0       not-in-family        Saab
# 28804              1229.88        4674160                wife      Accura
# 28805              1341.72        4000000                wife  Volkswagen
#
#       VehicleModel  VehicleYOM
# 0             E400        2005
# 1       Highlander        2010
# 2           Passat        2002
# 3       Highlander        2011
# 4         Wrangler        2010
# ...            ...         ...
# 28801          RSX        2002
# 28802          RSX        2014
# 28803          RSX        2013
# 28804          RSX        2004
# 28805          RSX        2009
#
# [28806 rows x 36 columns]

# %%
df['ReportedFraud'] = [1 if x == 'Y' else 0 for x in df['ReportedFraud']]

# %%
df['MonthOfIncident'] = pd.to_datetime(df['DateOfIncident']).dt.month
df['DayOfIncident'] = pd.to_datetime(df['DateOfIncident']).dt.day
df['MonthOfPolicyCoverage'] = pd.to_datetime(df['DateOfPolicyCoverage']).dt.month
df['DayOfPolicyCoverage'] = pd.to_datetime(df['DateOfPolicyCoverage']).dt.day

# %% [markdown]
# # Train Test Split

# %%
# split train test val in 80/10/10
train, test = train_test_split(df, stratify=df['ReportedFraud'], test_size=0.1)
train, val = train_test_split(train, stratify=df.loc[train.index, "ReportedFraud"], test_size=1/9)

# %% [markdown]
# # One Hot Encoding on Categorical Variables

# %%
cat_cols = ['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident', 'AuthoritiesContacted', 'IncidentState',
       'IncidentCity', 'PropertyDamage', 'Witnesses', 'PoliceReport', 'InsuredGender', 'InsuredEducationLevel',
       'InsuredOccupation', 'InsuredHobbies', 'InsurancePolicyState', 'Policy_CombinedSingleLimit', 'InsuredRelationship',
       'VehicleMake', 'VehicleModel']
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_cols = train.select_dtypes(include=numerics).columns.tolist()

dummy_cols = pd.get_dummies(train[cat_cols])
dummy_cols
train_ohe = pd.concat([train[numeric_cols], dummy_cols], axis = 1)
train_ohe.shape
# Out:
# (23044, 177)

# %%
cat_cols = ['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident', 'AuthoritiesContacted', 'IncidentState',
       'IncidentCity', 'PropertyDamage', 'Witnesses', 'PoliceReport', 'InsuredGender', 'InsuredEducationLevel',
       'InsuredOccupation', 'InsuredHobbies', 'InsurancePolicyState', 'Policy_CombinedSingleLimit', 'InsuredRelationship',
       'VehicleMake', 'VehicleModel']
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_cols = test.select_dtypes(include=numerics).columns.tolist()

dummy_cols = pd.get_dummies(test[cat_cols])
dummy_cols
test_ohe = pd.concat([test[numeric_cols], dummy_cols], axis = 1)
test_ohe.shape
# Out:
# (2881, 177)

# %%
cat_cols = ['TypeOfIncident', 'TypeOfCollission', 'SeverityOfIncident', 'AuthoritiesContacted', 'IncidentState',
       'IncidentCity', 'PropertyDamage', 'Witnesses', 'PoliceReport', 'InsuredGender', 'InsuredEducationLevel',
       'InsuredOccupation', 'InsuredHobbies', 'InsurancePolicyState', 'Policy_CombinedSingleLimit', 'InsuredRelationship',
       'VehicleMake', 'VehicleModel']
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_cols = val.select_dtypes(include=numerics).columns.tolist()

dummy_cols = pd.get_dummies(val[cat_cols])
dummy_cols
val_ohe = pd.concat([val[numeric_cols], dummy_cols], axis = 1)
val_ohe.shape
# Out:
# (2881, 177)

# %%
# Split IV and DV
X_train = train_ohe.iloc[:,1:]
y_train = train_ohe['ReportedFraud'] 

X_val = val_ohe.iloc[:,1:]
y_val = val_ohe['ReportedFraud']

X_test = test_ohe.iloc[:,1:]
y_test = test_ohe['ReportedFraud']

# %% [markdown]
# ## Dealing with Class Imbalance using SMOTE

# %%
smote = SMOTE()

# fit predictor and target variable
X_smote, y_smote = smote.fit_resample(X_train, y_train)
print('Original dataset shape', Counter(y_train))
print('Resample dataset shape', Counter(y_smote))
# Out:
# Original dataset shape Counter({0: 16820, 1: 6224})
# Resample dataset shape Counter({0: 16820, 1: 16820})

# %%
X_smote.to_csv('data/X_smote.csv', index=False)
y_smote.to_csv('data/y_smote.csv', index=False)

X_test.to_csv('data/X_test.csv', index=False)
y_test.to_csv('data/y_test.csv', index=False)

X_val.to_csv('data/X_val.csv', index=False)
y_val.to_csv('data/y_val.csv', index=False)
